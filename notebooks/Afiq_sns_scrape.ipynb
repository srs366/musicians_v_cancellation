# %%
pip install snscrape
# Out:
# Requirement already satisfied: snscrape in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (0.4.3.20220106)
# Requirement already satisfied: requests[socks] in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from snscrape) (2.28.1)
# Requirement already satisfied: pytz in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from snscrape) (2022.2.1)
# Requirement already satisfied: filelock in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from snscrape) (3.8.0)
# Requirement already satisfied: lxml in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from beautifulsoup4->snscrape) (2.3.2.post1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from requests[socks]->snscrape) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from requests[socks]->snscrape) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/malaiafiq/.pyenv/versions/3.8.12/envs/cancelled/lib/python3.8/site-packages (from requests[socks]->snscrape) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import snscrape.modules.twitter as sntwitter
from datetime import datetime,timedelta
import pandas as pd
def run_the_tweet(first_date,second_date, min_retweets, language):
    tweets_list= []
    for x in range(5):
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'Chris Brown since:{first_date} until:{second_date}  min_retweets:{min_retweets} lang:{language}').get_items()):
            if i > 4:
                break
            else:
                tweets_list.append([tweet.date, tweet.retweetCount, tweet.likeCount, tweet.content, tweet.user.username])
        if x < 5:
            first_date = datetime.strptime(first_date, '%Y-%m-%d') + timedelta(days=1)
            first_date = first_date.strftime('%Y-%m-%d')
            second_date = datetime.strptime(second_date, '%Y-%m-%d') + timedelta(days=1)
            second_date = second_date.strftime('%Y-%m-%d')
        else:
            break
    tweets_df = pd.DataFrame(tweets_list, columns=['Datetime',"retweet","likes", 'Text', 'Username'])
    return tweets_df
text = run_the_tweet("2021-10-27","2021-10-28", "5", "en")
text
# Out:
#                     Datetime  retweet  likes  \
# 0  2021-10-27 23:52:51+00:00       27    393
# 1  2021-10-27 23:39:48+00:00        8     44
# 2  2021-10-27 20:45:32+00:00       47    293
# 3  2021-10-27 20:32:06+00:00       10     42
# 4  2021-10-27 20:04:21+00:00       12     67
# 5  2021-10-28 23:35:08+00:00       56    317
# 6  2021-10-28 22:12:55+00:00       28    194
# 7  2021-10-28 21:58:23+00:00       14    149
# 8  2021-10-28 21:15:21+00:00       16      8
# 9  2021-10-28 21:04:24+00:00       33    329
# 10 2021-10-29 23:25:55+00:00        7     15
# 11 2021-10-29 23:25:49+00:00       57    304
# 12 2021-10-29 22:48:12+00:00      104    456
# 13 2021-10-29 21:00:02+00:00       15    173
# 14 2021-10-29 20:53:09+00:00       19    137
# 15 2021-10-30 23:27:50+00:00      239   1245
# 16 2021-10-30 23:25:58+00:00        5     38
# 17 2021-10-30 22:03:53+00:00        7     33
# 18 2021-10-30 21:15:53+00:00      308   2692
# 19 2021-10-30 20:09:17+00:00       14     44
# 20 2021-10-31 23:42:24+00:00       13     39
# 21 2021-10-31 23:30:01+00:00        9    239
# 22 2021-10-31 22:42:00+00:00        8     43
# 23 2021-10-31 21:30:10+00:00        9     20
# 24 2021-10-31 21:00:40+00:00       99    770
#
#                                                  Text         Username
# 0         chris brown | 2014. https://t.co/3uQ0PtoAWP        isbreezyy
# 1   This Friday! \n\n@OHYESMARIO Feat. @chrisbrown...    cbreezyvideos
# 2   NEWS: @OHYESMARIO will be releasing his new si...     ChartsBreezy
# 3   CMA Awards Adds Chris Stapleton, Carrie Underw...           people
# 4   Mario ft Chris Brown this friday https://t.co/...    BreezyftJimin
# 5   Mario is back with a new bop featuring Chris B...     TheShadeRoom
# 6   .@chrisbrown via Instagram.\n\n“Who want smoke...          cblivee
# 7         chris brown | 2019. https://t.co/TU8883GcOl        isbreezyy
# 8   Here’s a song for you - AFRICAN BAD GYAL by ⁦@...         Big__ema
# 9   New music from JAY-Z, Kid Cudi, YG, Young Thug...       StrappedHH
# 10  Jordin Sparks No air Feat Chris fucking Mauric...     BaayMoBreezy
# 11  The thing that I’ll never understand about thi...       hesswesley
# 12  chris brown a legend. fuck what y'all talking ...  papichulllooooo
# 13  Chris Brown with friends recently. https://t.c...          cblivee
# 14  .@chrisbrown links up with artists in LA recen...   chrisbrownewss
# 15  Charlie Clips vs Chess going down at Chris Bro...          DatPiff
# 16  🎉🥂🍾 𝙀𝙖𝙨𝙮 𝙍𝙀𝙈𝙄𝙓 - @iamDaniLeigh 𝙛𝙩. @chrisbrown...      TB_Vanguard
# 17  I heard somebody went to Chris brown house and...    MackMel_GRECM
# 18  Players out Sunday include Antonio Brown, Tays...     AdamSchefter
# 19  Today Kenneth Walker III of @MSU_Football beca...     StatsBySTATS
# 20  One of the biggest film upsets, has to be Chri...  Far_FromAveraqe
# 21  His tenure has been rocky ever since 2015, how...        RedditCFB
# 22  #Steelers Injury Updates: Kicker Chris Boswell...   PghSteelersNow
# 23  chris brown da goat fr..y’all gone wanna give ...      _BlaccJesus
# 24  Thank you to @Drake for extending the invitati...       RealSikh99

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

import string
import re

from wordcloud import STOPWORDS
from emot.emo_unicode import UNICODE_EMOJI

lemmatizer = WordNetLemmatizer()
eng_stop_words = list(stopwords.words('english'))
emoji = list(UNICODE_EMOJI.keys())

def clean_text(text):
    #changing to lowercase
    text = text.lower()
    # removing @ and links
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # removing repeating characters
    text = re.sub(r'\@\w+|\#\w+|\d+','',text)
    #removing punctuatuon and numbers
    punct = str.maketrans('', '', string.punctuation+string.digits)
    #tokenizing words and removing stop words from text
    tokens = word_tokenize(text)
    filtered_words = [w for w in tokens if w not in eng_stop_words]
    filtered_words = [w for w in filtered_words if w not in emoji]
    #lemmetizing words
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w) for w in filtered_words]
    text = " ".join(lemma_words)
    return text
#run the function
text['Text'] = text['Text'].apply(clean_text)
text
# Out:
#                     Datetime  retweet  likes  \
# 0  2021-10-27 23:52:51+00:00       27    393
# 1  2021-10-27 23:39:48+00:00        8     44
# 2  2021-10-27 20:45:32+00:00       47    293
# 3  2021-10-27 20:32:06+00:00       10     42
# 4  2021-10-27 20:04:21+00:00       12     67
# 5  2021-10-28 23:35:08+00:00       56    317
# 6  2021-10-28 22:12:55+00:00       28    194
# 7  2021-10-28 21:58:23+00:00       14    149
# 8  2021-10-28 21:15:21+00:00       16      8
# 9  2021-10-28 21:04:24+00:00       33    329
# 10 2021-10-29 23:25:55+00:00        7     15
# 11 2021-10-29 23:25:49+00:00       57    304
# 12 2021-10-29 22:48:12+00:00      104    456
# 13 2021-10-29 21:00:02+00:00       15    173
# 14 2021-10-29 20:53:09+00:00       19    137
# 15 2021-10-30 23:27:50+00:00      239   1245
# 16 2021-10-30 23:25:58+00:00        5     38
# 17 2021-10-30 22:03:53+00:00        7     33
# 18 2021-10-30 21:15:53+00:00      308   2692
# 19 2021-10-30 20:09:17+00:00       14     44
# 20 2021-10-31 23:42:24+00:00       13     39
# 21 2021-10-31 23:30:01+00:00        9    239
# 22 2021-10-31 22:42:00+00:00        8     43
# 23 2021-10-31 21:30:10+00:00        9     20
# 24 2021-10-31 21:00:40+00:00       99    770
#
#                                                  Text         Username
# 0                                         chris brown        isbreezyy
# 1                                friday feat get back    cbreezyvideos
# 2        news releasing new single get back ft friday     ChartsBreezy
# 3   cma award add chris stapleton carrie underwood...           people
# 4                         mario ft chris brown friday    BreezyftJimin
# 5   mario back new bop featuring chris brown exclu...     TheShadeRoom
# 6                        via instagram want smoke wit          cblivee
# 7                                         chris brown        isbreezyy
# 8   here song african bad gyal ft chris brown via ...         Big__ema
# 9   new music jayz kid cudi yg young thug gunna li...       StrappedHH
# 10  jordin spark air feat chris fucking maurice brown     BaayMoBreezy
# 11  thing ill never understand vaccine thing anger...       hesswesley
# 12  chris brown legend fuck yall talking bout nigg...  papichulllooooo
# 13                        chris brown friend recently          cblivee
# 14                            link artist la recently   chrisbrownewss
# 15       charlie clip v chess going chris brown house          DatPiff
# 16     achieved triple platinum status congratulation      TB_Vanguard
# 17  heard somebody went chris brown house grab han...    MackMel_GRECM
# 18  player sunday include antonio brown taysom hil...     AdamSchefter
# 19  today kenneth walker iii football became first...     StatsBySTATS
# 20  one biggest film upset chris brown dying first...  Far_FromAveraqe
# 21  tenure rocky ever since however despite taking...        RedditCFB
# 22  steelers injury update kicker chris boswell sa...   PghSteelersNow
# 23  chris brown da goat fryall gone wan na give fl...      _BlaccJesus
# 24  thank extending invitation thank amazing battl...       RealSikh99

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

import string
import re

from wordcloud import STOPWORDS
from emot.emo_unicode import UNICODE_EMOJI

lemmatizer = WordNetLemmatizer()


#eng_stop_words = list(stopwords.words('english'))
emoji = list(UNICODE_EMOJI.keys())

def clean_text(text):
    #changing to lowercase
    text = text.lower()
    # removing @ and links
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # removing repeating characters
    text = re.sub(r'\@\w+|\#\w+|\d+','',text)
    #removing punctuatuon and numbers
    punct = str.maketrans('', '', string.punctuation+string.digits)
    #tokenizing words and removing stop words from text
    tokens = word_tokenize(text)
    #filtered_words = [w for w in tokens if w not in eng_stop_words]
    filtered_words = [w for w in tokens if w not in emoji]
    #lemmetizing words
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w) for w in filtered_words]
    text = " ".join(lemma_words)
    return text
#run the function
text['New_text'] = text['Text'].apply(clean_text)
text.head()
# Out:
#                    Datetime  retweet  likes  \
# 0 2021-10-27 23:52:51+00:00       27    393
# 1 2021-10-27 23:39:48+00:00        8     44
# 2 2021-10-27 20:45:32+00:00       47    293
# 3 2021-10-27 20:32:06+00:00       10     42
# 4 2021-10-27 20:04:21+00:00       12     67
#
#                                                 Text       Username  \
# 0                                        chris brown      isbreezyy
# 1                               friday feat get back  cbreezyvideos
# 2       news releasing new single get back ft friday   ChartsBreezy
# 3  cma award add chris stapleton carrie underwood...         people
# 4                        mario ft chris brown friday  BreezyftJimin
#
#                                             New_text
# 0                                        chris brown
# 1                               friday feat get back
# 2       news releasing new single get back ft friday
# 3  cma award add chris stapleton carrie underwood...
# 4                        mario ft chris brown friday

# %%
import textblob

from textblob import TextBlob

def polarity(tweet):
    return TextBlob(tweet).sentiment.polarity

def sentimenttextblob(polarity):
    if polarity < 0:
        return "Negative"
    elif polarity == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
text["Polarity"] = text["New_text"].apply(polarity)
text["Sentiment"] = text["Polarity"].apply(sentimenttextblob)
sent = text["Sentiment"].value_counts()
sent
text
# Out:
#                     Datetime  retweet  likes  \
# 0  2021-10-27 23:52:51+00:00       27    393
# 1  2021-10-27 23:39:48+00:00        8     44
# 2  2021-10-27 20:45:32+00:00       47    293
# 3  2021-10-27 20:32:06+00:00       10     42
# 4  2021-10-27 20:04:21+00:00       12     67
# 5  2021-10-28 23:35:08+00:00       56    317
# 6  2021-10-28 22:12:55+00:00       28    194
# 7  2021-10-28 21:58:23+00:00       14    149
# 8  2021-10-28 21:15:21+00:00       16      8
# 9  2021-10-28 21:04:24+00:00       33    329
# 10 2021-10-29 23:25:55+00:00        7     15
# 11 2021-10-29 23:25:49+00:00       57    304
# 12 2021-10-29 22:48:12+00:00      104    456
# 13 2021-10-29 21:00:02+00:00       15    173
# 14 2021-10-29 20:53:09+00:00       19    137
# 15 2021-10-30 23:27:50+00:00      239   1245
# 16 2021-10-30 23:25:58+00:00        5     38
# 17 2021-10-30 22:03:53+00:00        7     33
# 18 2021-10-30 21:15:53+00:00      308   2692
# 19 2021-10-30 20:09:17+00:00       14     44
# 20 2021-10-31 23:42:24+00:00       13     39
# 21 2021-10-31 23:30:01+00:00        9    239
# 22 2021-10-31 22:42:00+00:00        8     43
# 23 2021-10-31 21:30:10+00:00        9     20
# 24 2021-10-31 21:00:40+00:00       99    770
#
#                                                  Text         Username  \
# 0                                         chris brown        isbreezyy
# 1                                friday feat get back    cbreezyvideos
# 2        news releasing new single get back ft friday     ChartsBreezy
# 3   cma award add chris stapleton carrie underwood...           people
# 4                         mario ft chris brown friday    BreezyftJimin
# 5   mario back new bop featuring chris brown exclu...     TheShadeRoom
# 6                        via instagram want smoke wit          cblivee
# 7                                         chris brown        isbreezyy
# 8   here song african bad gyal ft chris brown via ...         Big__ema
# 9   new music jayz kid cudi yg young thug gunna li...       StrappedHH
# 10  jordin spark air feat chris fucking maurice brown     BaayMoBreezy
# 11  thing ill never understand vaccine thing anger...       hesswesley
# 12  chris brown legend fuck yall talking bout nigg...  papichulllooooo
# 13                        chris brown friend recently          cblivee
# 14                            link artist la recently   chrisbrownewss
# 15       charlie clip v chess going chris brown house          DatPiff
# 16     achieved triple platinum status congratulation      TB_Vanguard
# 17  heard somebody went chris brown house grab han...    MackMel_GRECM
# 18  player sunday include antonio brown taysom hil...     AdamSchefter
# 19  today kenneth walker iii football became first...     StatsBySTATS
# 20  one biggest film upset chris brown dying first...  Far_FromAveraqe
# 21  tenure rocky ever since however despite taking...        RedditCFB
# 22  steelers injury update kicker chris boswell sa...   PghSteelersNow
# 23  chris brown da goat fryall gone wan na give fl...      _BlaccJesus
# 24  thank extending invitation thank amazing battl...       RealSikh99
#
#                                              New_text  Polarity Sentiment
# 0                                         chris brown  0.000000   Neutral
# 1                                friday feat get back  0.000000   Neutral
# 2        news releasing new single get back ft friday  0.021645  Positive
# 3   cma award add chris stapleton carrie underwood...  0.000000   Neutral
# 4                         mario ft chris brown friday  0.000000   Neutral
# 5   mario back new bop featuring chris brown exclu...  0.068182  Positive
# 6                        via instagram want smoke wit  0.000000   Neutral
# 7                                         chris brown  0.000000   Neutral
# 8   here song african bad gyal ft chris brown via ... -0.350000  Negative
# 9   new music jayz kid cudi yg young thug gunna li... -0.052727  Negative
# 10  jordin spark air feat chris fucking maurice brown -0.600000  Negative
# 11  thing ill never understand vaccine thing anger... -0.400000  Negative
# 12  chris brown legend fuck yall talking bout nigg... -0.400000  Negative
# 13                        chris brown friend recently  0.000000   Neutral
# 14                            link artist la recently  0.000000   Neutral
# 15       charlie clip v chess going chris brown house  0.000000   Neutral
# 16     achieved triple platinum status congratulation  0.000000   Neutral
# 17  heard somebody went chris brown house grab han... -0.375000  Negative
# 18  player sunday include antonio brown taysom hil...  0.000000   Neutral
# 19  today kenneth walker iii football became first...  0.375000  Positive
# 20  one biggest film upset chris brown dying first...  0.250000  Positive
# 21  tenure rocky ever since however despite taking...  0.020000  Positive
# 22  steelers injury update kicker chris boswell sa... -0.052778  Negative
# 23  chris brown da goat fryall gone wan na give fl... -0.250000  Negative
# 24  thank extending invitation thank amazing battl...  0.366667  Positive
